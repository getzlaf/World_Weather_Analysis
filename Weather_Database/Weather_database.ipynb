# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 800

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Import the requests library.
import requests

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | kavieng
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | caravelas
# Processing Record 18 of Set 1 | huarmey
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | mulatupo
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | ayan
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | urumqi
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | lavrentiya
# Processing Record 33 of Set 1 | katobu
# Processing Record 34 of Set 1 | nurota
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | vostok
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | loandjili
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | fuling
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | baracoa
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | aswan
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | caldwell
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | kjollefjord
# Processing Record 3 of Set 2 | zhezkazgan
# Processing Record 4 of Set 2 | bainbridge
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | constitucion
# Processing Record 8 of Set 2 | lazaro cardenas
# Processing Record 9 of Set 2 | chinsali
# Processing Record 10 of Set 2 | christchurch
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | comodoro rivadavia
# Processing Record 13 of Set 2 | kununurra
# Processing Record 14 of Set 2 | tshikapa
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | kirakira
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | aykhal
# Processing Record 28 of Set 2 | hazorasp
# Processing Record 29 of Set 2 | valdivia
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | salon
# Processing Record 33 of Set 2 | sharjah
# Processing Record 34 of Set 2 | innisfail
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | verkhnyaya maksakovka
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | ust-nera
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | saint-georges
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | iracoubo
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 3 | kouroussa
# Processing Record 3 of Set 3 | skibbereen
# Processing Record 4 of Set 3 | taoudenni
# Processing Record 5 of Set 3 | tallahassee
# Processing Record 6 of Set 3 | mafeteng
# Processing Record 7 of Set 3 | acari
# Processing Record 8 of Set 3 | nelson bay
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | ushuaia
# Processing Record 11 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 3 | acapulco
# Processing Record 13 of Set 3 | tingo maria
# Processing Record 14 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 3 | kieta
# Processing Record 16 of Set 3 | fuxin
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | te anau
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | lompoc
# Processing Record 21 of Set 3 | la sarre
# Processing Record 22 of Set 3 | akdepe
# Processing Record 23 of Set 3 | kailua
# Processing Record 24 of Set 3 | karamken
# City not found. Skipping...
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | juegang
# Processing Record 27 of Set 3 | haines junction
# Processing Record 28 of Set 3 | sanmenxia
# Processing Record 29 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 3 | nushki
# Processing Record 31 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | gudiyattam
# City not found. Skipping...
# Processing Record 33 of Set 3 | princeton
# Processing Record 34 of Set 3 | dhandhuka
# Processing Record 35 of Set 3 | guia de isora
# Processing Record 36 of Set 3 | barkot
# Processing Record 37 of Set 3 | alangayam
# Processing Record 38 of Set 3 | puerto leguizamo
# Processing Record 39 of Set 3 | cervo
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | bargarh
# Processing Record 42 of Set 3 | natal
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | along
# Processing Record 45 of Set 3 | iranshahr
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | arenapolis
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | geraldton
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | griffith
# Processing Record 2 of Set 4 | pemangkat
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | jiblah
# Processing Record 5 of Set 4 | tambilil
# Processing Record 6 of Set 4 | bima
# Processing Record 7 of Set 4 | oussouye
# Processing Record 8 of Set 4 | jamame
# Processing Record 9 of Set 4 | frontera
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | marawi
# Processing Record 14 of Set 4 | kochi
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 4 | isoka
# Processing Record 18 of Set 4 | belyy yar
# Processing Record 19 of Set 4 | steamboat springs
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | yerbogachen
# Processing Record 22 of Set 4 | oistins
# Processing Record 23 of Set 4 | namie
# Processing Record 24 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | hualmay
# Processing Record 29 of Set 4 | conceicao da barra
# Processing Record 30 of Set 4 | wilkie
# Processing Record 31 of Set 4 | hami
# Processing Record 32 of Set 4 | druzhba
# Processing Record 33 of Set 4 | lagoa
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | tual
# Processing Record 36 of Set 4 | nalhati
# Processing Record 37 of Set 4 | mao
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 4 | ust-tsilma
# Processing Record 42 of Set 4 | camarillo
# Processing Record 43 of Set 4 | beringovskiy
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | tanhacu
# Processing Record 46 of Set 4 | tecoanapa
# Processing Record 47 of Set 4 | kondinskoye
# Processing Record 48 of Set 4 | arkhara
# Processing Record 49 of Set 4 | butaritari
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 5 | dingle
# Processing Record 3 of Set 5 | aybak
# City not found. Skipping...
# Processing Record 4 of Set 5 | hambantota
# Processing Record 5 of Set 5 | wasilla
# Processing Record 6 of Set 5 | vila franca do campo
# Processing Record 7 of Set 5 | phan thiet
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | orocue
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | kitgum
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | nago
# Processing Record 16 of Set 5 | bocas del toro
# Processing Record 17 of Set 5 | barrow
# Processing Record 18 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 5 | luanda
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | cabedelo
# Processing Record 22 of Set 5 | mabaruma
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | utraula
# Processing Record 25 of Set 5 | san isidro
# Processing Record 26 of Set 5 | ketchikan
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | exeter
# Processing Record 29 of Set 5 | klaksvik
# Processing Record 30 of Set 5 | navapur
# City not found. Skipping...
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | bonavista
# Processing Record 34 of Set 5 | necochea
# Processing Record 35 of Set 5 | paeroa
# Processing Record 36 of Set 5 | aras
# Processing Record 37 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 38 of Set 5 | lashio
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | maceio
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | porto walter
# Processing Record 44 of Set 5 | parksville
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | wolmaranstad
# City not found. Skipping...
# Processing Record 47 of Set 5 | gorontalo
# Processing Record 48 of Set 5 | fort frances
# Processing Record 49 of Set 5 | maseru
# Processing Record 50 of Set 5 | katherine
# Processing Record 1 of Set 6 | puerto ayora
# Processing Record 2 of Set 6 | koumac
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | iwanai
# Processing Record 5 of Set 6 | gamba
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | tempio pausania
# Processing Record 8 of Set 6 | torbay
# Processing Record 9 of Set 6 | fushe-arrez
# Processing Record 10 of Set 6 | sallama
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | fukuma
# Processing Record 13 of Set 6 | sorland
# Processing Record 14 of Set 6 | lethem
# Processing Record 15 of Set 6 | olinda
# Processing Record 16 of Set 6 | havoysund
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | sola
# Processing Record 19 of Set 6 | nador
# Processing Record 20 of Set 6 | lexington
# Processing Record 21 of Set 6 | goderich
# Processing Record 22 of Set 6 | lakhipur
# Processing Record 23 of Set 6 | hay river
# Processing Record 24 of Set 6 | zhigalovo
# Processing Record 25 of Set 6 | saint-augustin
# Processing Record 26 of Set 6 | khovu-aksy
# Processing Record 27 of Set 6 | leh
# Processing Record 28 of Set 6 | samarai
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | kangaatsiaq
# Processing Record 31 of Set 6 | suntar
# Processing Record 32 of Set 6 | berekum
# Processing Record 33 of Set 6 | fairbanks
# Processing Record 34 of Set 6 | kribi
# Processing Record 35 of Set 6 | rocky mountain house
# Processing Record 36 of Set 6 | knysna
# Processing Record 37 of Set 6 | torres
# Processing Record 38 of Set 6 | vao
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | nemuro
# Processing Record 45 of Set 6 | kazachinskoye
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | erenhot
# Processing Record 48 of Set 6 | paragominas
# Processing Record 49 of Set 6 | awjilah
# Processing Record 50 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 7 | saint michael
# Processing Record 2 of Set 7 | laibin
# Processing Record 3 of Set 7 | ongandjera
# Processing Record 4 of Set 7 | namatanai
# Processing Record 5 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | camacha
# Processing Record 8 of Set 7 | flinders
# Processing Record 9 of Set 7 | corinth
# Processing Record 10 of Set 7 | prudentopolis
# Processing Record 11 of Set 7 | san jose
# Processing Record 12 of Set 7 | bayan
# Processing Record 13 of Set 7 | taos
# Processing Record 14 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 7 | sioux lookout
# Processing Record 16 of Set 7 | verkhnevilyuysk
# Processing Record 17 of Set 7 | mbandaka
# Processing Record 18 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | sulangan
# Processing Record 21 of Set 7 | jacareacanga
# Processing Record 22 of Set 7 | mitsamiouli
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | tarko-sale
# Processing Record 25 of Set 7 | avenal
# Processing Record 26 of Set 7 | qinhuangdao
# Processing Record 27 of Set 7 | yuzhno-kurilsk
# Processing Record 28 of Set 7 | tilichiki
# Processing Record 29 of Set 7 | port shepstone
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | machiques
# Processing Record 32 of Set 7 | lata
# Processing Record 33 of Set 7 | samut sakhon
# Processing Record 34 of Set 7 | kalmunai
# Processing Record 35 of Set 7 | takoradi
# Processing Record 36 of Set 7 | eyl
# Processing Record 37 of Set 7 | livingston
# Processing Record 38 of Set 7 | hun
# Processing Record 39 of Set 7 | dongsheng
# Processing Record 40 of Set 7 | esik
# Processing Record 41 of Set 7 | barinitas
# Processing Record 42 of Set 7 | ippy
# Processing Record 43 of Set 7 | byron bay
# Processing Record 44 of Set 7 | christiana
# Processing Record 45 of Set 7 | dogongan
# Processing Record 46 of Set 7 | dharchula
# Processing Record 47 of Set 7 | roald
# Processing Record 48 of Set 7 | bengkulu
# Processing Record 49 of Set 7 | ruteng
# Processing Record 50 of Set 7 | leshukonskoye
# Processing Record 1 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 8 | zemio
# Processing Record 3 of Set 8 | kampot
# Processing Record 4 of Set 8 | vestmannaeyjar
# Processing Record 5 of Set 8 | channel-port aux basques
# Processing Record 6 of Set 8 | ambon
# Processing Record 7 of Set 8 | asau
# Processing Record 8 of Set 8 | tuatapere
# Processing Record 9 of Set 8 | zaozerne
# Processing Record 10 of Set 8 | malatya
# Processing Record 11 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 12 of Set 8 | qaqortoq
# Processing Record 13 of Set 8 | dwarka
# Processing Record 14 of Set 8 | alyangula
# Processing Record 15 of Set 8 | paredon
# Processing Record 16 of Set 8 | ler
# Processing Record 17 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 8 | bontang
# Processing Record 19 of Set 8 | kousseri
# Processing Record 20 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 21 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 23 of Set 8 | port macquarie
# Processing Record 24 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 8 | paraiso
# Processing Record 26 of Set 8 | ambilobe
# Processing Record 27 of Set 8 | ushtobe
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | atambua
# Processing Record 30 of Set 8 | arman
# Processing Record 31 of Set 8 | novobirilyussy
# Processing Record 32 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 8 | mahon
# Processing Record 34 of Set 8 | yining
# Processing Record 35 of Set 8 | don sak
# Processing Record 36 of Set 8 | herstal
# Processing Record 37 of Set 8 | kokkola
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | kumo
# Processing Record 40 of Set 8 | plyussa
# Processing Record 41 of Set 8 | kismayo
# Processing Record 42 of Set 8 | leningradskiy
# Processing Record 43 of Set 8 | general roca
# Processing Record 44 of Set 8 | daru
# Processing Record 45 of Set 8 | bilma
# Processing Record 46 of Set 8 | richards bay
# Processing Record 47 of Set 8 | sakaiminato
# Processing Record 48 of Set 8 | bukachacha
# Processing Record 49 of Set 8 | praia da vitoria
# Processing Record 50 of Set 8 | roma
# Processing Record 1 of Set 9 | yershichi
# Processing Record 2 of Set 9 | grand gaube
# Processing Record 3 of Set 9 | bafra
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | coolum beach
# Processing Record 6 of Set 9 | severodvinsk
# Processing Record 7 of Set 9 | san juan
# Processing Record 8 of Set 9 | yanliang
# Processing Record 9 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 9 | nizhniy ingash
# Processing Record 11 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 12 of Set 9 | at-bashi
# Processing Record 13 of Set 9 | lukulu
# Processing Record 14 of Set 9 | bilibino
# Processing Record 15 of Set 9 | tilbury
# Processing Record 16 of Set 9 | burnie
# Processing Record 17 of Set 9 | andra
# Processing Record 18 of Set 9 | ibadan
# Processing Record 19 of Set 9 | lebu
# Processing Record 20 of Set 9 | yabrud
# Processing Record 21 of Set 9 | kawalu
# Processing Record 22 of Set 9 | kpagouda
# City not found. Skipping...
# Processing Record 23 of Set 9 | akyab
# Processing Record 24 of Set 9 | davenport
# Processing Record 25 of Set 9 | rincon
# Processing Record 26 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 9 | shenjiamen
# Processing Record 28 of Set 9 | glenwood springs
# Processing Record 29 of Set 9 | katangli
# Processing Record 30 of Set 9 | lufilufi
# Processing Record 31 of Set 9 | poum
# Processing Record 32 of Set 9 | burica
# City not found. Skipping...
# Processing Record 33 of Set 9 | cairns
# Processing Record 34 of Set 9 | sorong
# Processing Record 35 of Set 9 | banjar
# Processing Record 36 of Set 9 | hobyo
# Processing Record 37 of Set 9 | ciudad bolivar
# Processing Record 38 of Set 9 | ibateguara
# Processing Record 39 of Set 9 | waddan
# Processing Record 40 of Set 9 | honiara
# Processing Record 41 of Set 9 | nabire
# Processing Record 42 of Set 9 | baykit
# Processing Record 43 of Set 9 | mastic beach
# Processing Record 44 of Set 9 | kidal
# Processing Record 45 of Set 9 | lakshmeshwar
# Processing Record 46 of Set 9 | galveston
# Processing Record 47 of Set 9 | atasu
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | yaan
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | rapid valley
# Processing Record 2 of Set 10 | borovoy
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | henties bay
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | sechura
# Processing Record 7 of Set 10 | sretensk
# Processing Record 8 of Set 10 | viedma
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | seoul
# Processing Record 11 of Set 10 | beidao
# Processing Record 12 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 10 | jieshi
# Processing Record 14 of Set 10 | santa rosa
# Processing Record 15 of Set 10 | moerai
# Processing Record 16 of Set 10 | savinskiy
# Processing Record 17 of Set 10 | tezu
# Processing Record 18 of Set 10 | gayeri
# Processing Record 19 of Set 10 | maragogi
# Processing Record 20 of Set 10 | iqaluit
# Processing Record 21 of Set 10 | haikou
# Processing Record 22 of Set 10 | contamana
# Processing Record 23 of Set 10 | powell river
# Processing Record 24 of Set 10 | port keats
# Processing Record 25 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 10 | opunake
# Processing Record 27 of Set 10 | puerto del rosario
# Processing Record 28 of Set 10 | rawson
# Processing Record 29 of Set 10 | kropotkin
# Processing Record 30 of Set 10 | imbituba
# Processing Record 31 of Set 10 | kambove
# Processing Record 32 of Set 10 | tulum
# Processing Record 33 of Set 10 | japura
# Processing Record 34 of Set 10 | jumla
# Processing Record 35 of Set 10 | abu samrah
# Processing Record 36 of Set 10 | krasnogorsk
# Processing Record 37 of Set 10 | racine
# Processing Record 38 of Set 10 | sohag
# Processing Record 39 of Set 10 | berlevag
# Processing Record 40 of Set 10 | duma
# Processing Record 41 of Set 10 | mandurah
# Processing Record 42 of Set 10 | timmins
# Processing Record 43 of Set 10 | dukat
# Processing Record 44 of Set 10 | mackay
# Processing Record 45 of Set 10 | careiro da varzea
# Processing Record 46 of Set 10 | arusha
# Processing Record 47 of Set 10 | carmo do rio claro
# Processing Record 48 of Set 10 | baragua
# Processing Record 49 of Set 10 | lahaina
# Processing Record 50 of Set 10 | tungor
# Processing Record 1 of Set 11 | palana
# Processing Record 2 of Set 11 | xinpu
# Processing Record 3 of Set 11 | salta
# Processing Record 4 of Set 11 | suure-jaani
# Processing Record 5 of Set 11 | mangaratiba
# Processing Record 6 of Set 11 | bowen
# Processing Record 7 of Set 11 | salalah
# Processing Record 8 of Set 11 | kamaishi
# Processing Record 9 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 11 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 13 of Set 11 | talaya
# Processing Record 14 of Set 11 | batemans bay
# Processing Record 15 of Set 11 | narasannapeta
# Processing Record 16 of Set 11 | kruisfontein
# Processing Record 17 of Set 11 | praia
# Processing Record 18 of Set 11 | xuddur
# Processing Record 19 of Set 11 | nakambala
# Processing Record 20 of Set 11 | hongjiang
# Processing Record 21 of Set 11 | newport
# Processing Record 22 of Set 11 | tommot
# Processing Record 23 of Set 11 | kopyevo
# City not found. Skipping...
# Processing Record 24 of Set 11 | tucuman
# Processing Record 25 of Set 11 | oktyabrskoye
# Processing Record 26 of Set 11 | oranjestad
# Processing Record 27 of Set 11 | casablanca
# Processing Record 28 of Set 11 | boysun
# Processing Record 29 of Set 11 | gizo
# Processing Record 30 of Set 11 | vardo
# Processing Record 31 of Set 11 | ambanja
# Processing Record 32 of Set 11 | ulladulla
# Processing Record 33 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 11 | itaituba
# Processing Record 35 of Set 11 | gwadar
# Processing Record 36 of Set 11 | takaka
# Processing Record 37 of Set 11 | khonsar
# City not found. Skipping...
# Processing Record 38 of Set 11 | cockburn town
# Processing Record 39 of Set 11 | inhambane
# Processing Record 40 of Set 11 | pundaguitan
# Processing Record 41 of Set 11 | ternate
# Processing Record 42 of Set 11 | vila
# Processing Record 43 of Set 11 | adre
# Processing Record 44 of Set 11 | cayenne
# Processing Record 45 of Set 11 | inuvik
# Processing Record 46 of Set 11 | nantucket
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | vestmanna
# Processing Record 49 of Set 11 | manaus
# Processing Record 50 of Set 11 | aksarka
# Processing Record 1 of Set 12 | hovd
# Processing Record 2 of Set 12 | port-gentil
# Processing Record 3 of Set 12 | sarangani
# Processing Record 4 of Set 12 | adet
# Processing Record 5 of Set 12 | qostanay
# Processing Record 6 of Set 12 | prainha
# Processing Record 7 of Set 12 | komsomolskiy
# Processing Record 8 of Set 12 | zunyi
# Processing Record 9 of Set 12 | marzuq
# Processing Record 10 of Set 12 | saleilua
# City not found. Skipping...
# Processing Record 11 of Set 12 | bouna
# Processing Record 12 of Set 12 | kloulklubed
# Processing Record 13 of Set 12 | garzon
# Processing Record 14 of Set 12 | anito
# Processing Record 15 of Set 12 | sao filipe
# Processing Record 16 of Set 12 | lodwar
# Processing Record 17 of Set 12 | angoche
# Processing Record 18 of Set 12 | ahuimanu
# Processing Record 19 of Set 12 | nouadhibou
# Processing Record 20 of Set 12 | nome
# Processing Record 21 of Set 12 | surt
# Processing Record 22 of Set 12 | olafsvik
# Processing Record 23 of Set 12 | roebourne
# Processing Record 24 of Set 12 | la peca
# Processing Record 25 of Set 12 | ankazobe
# Processing Record 26 of Set 12 | sucre
# Processing Record 27 of Set 12 | kahului
# Processing Record 28 of Set 12 | yantal
# Processing Record 29 of Set 12 | vyshhorod
# Processing Record 30 of Set 12 | laurel
# Processing Record 31 of Set 12 | novoanninskiy
# Processing Record 32 of Set 12 | san francisco del mar
# Processing Record 33 of Set 12 | northam
# Processing Record 34 of Set 12 | borazjan
# Processing Record 35 of Set 12 | antofagasta
# Processing Record 36 of Set 12 | banda aceh
# Processing Record 37 of Set 12 | puga
# Processing Record 38 of Set 12 | mandera
# Processing Record 39 of Set 12 | safranbolu
# Processing Record 40 of Set 12 | egvekinot
# Processing Record 41 of Set 12 | kampene
# Processing Record 42 of Set 12 | coruripe
# Processing Record 43 of Set 12 | constantine
# Processing Record 44 of Set 12 | batagay-alyta
# Processing Record 45 of Set 12 | nyurba
# Processing Record 46 of Set 12 | boatlaname
# City not found. Skipping...
# Processing Record 47 of Set 12 | wa
# City not found. Skipping...
# Processing Record 48 of Set 12 | galesong
# Processing Record 49 of Set 12 | morvi
# Processing Record 50 of Set 12 | dire
# Processing Record 1 of Set 13 | harbour breton
# Processing Record 2 of Set 13 | yarada
# Processing Record 3 of Set 13 | monte cristi
# City not found. Skipping...
# Processing Record 4 of Set 13 | nola
# Processing Record 5 of Set 13 | manokwari
# Processing Record 6 of Set 13 | naze
# Processing Record 7 of Set 13 | zapolyarnyy
# Processing Record 8 of Set 13 | kisaran
# Processing Record 9 of Set 13 | tarauaca
# Processing Record 10 of Set 13 | perth
# Processing Record 11 of Set 13 | san carlos de bariloche
# Processing Record 12 of Set 13 | honningsvag
# Processing Record 13 of Set 13 | saint-joseph
# Processing Record 14 of Set 13 | abu dhabi
# Processing Record 15 of Set 13 | davidson
# Processing Record 16 of Set 13 | priargunsk
# Processing Record 17 of Set 13 | buraydah
# Processing Record 18 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 19 of Set 13 | puro
# Processing Record 20 of Set 13 | dosso
# Processing Record 21 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 13 | almeirim
# Processing Record 23 of Set 13 | dali
# Processing Record 24 of Set 13 | palmer
# Processing Record 25 of Set 13 | cap malheureux
# Processing Record 26 of Set 13 | gisborne
# Processing Record 27 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 13 | buarcos
# Processing Record 29 of Set 13 | lincoln
# Processing Record 30 of Set 13 | hervey bay
# Processing Record 31 of Set 13 | mahina
# Processing Record 32 of Set 13 | starogard gdanski
# Processing Record 33 of Set 13 | jinchang
# Processing Record 34 of Set 13 | union
# Processing Record 35 of Set 13 | road town
# Processing Record 36 of Set 13 | sisimiut
# Processing Record 37 of Set 13 | los llanos de aridane
# Processing Record 38 of Set 13 | bardiyah
# Processing Record 39 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 13 | gerede
# Processing Record 41 of Set 13 | taloqan
# Processing Record 42 of Set 13 | belaya gora
# Processing Record 43 of Set 13 | mayumba
# Processing Record 44 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 13 | bilecik
# Processing Record 46 of Set 13 | baoma
# Processing Record 47 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 13 | cardross
# Processing Record 49 of Set 13 | caucaia
# Processing Record 50 of Set 13 | zhob
# Processing Record 1 of Set 14 | ukiah
# Processing Record 2 of Set 14 | lhokseumawe
# Processing Record 3 of Set 14 | bluefields
# Processing Record 4 of Set 14 | bayshore gardens
# Processing Record 5 of Set 14 | smidovich
# Processing Record 6 of Set 14 | bridgetown
# Processing Record 7 of Set 14 | tigzirt
# Processing Record 8 of Set 14 | uruzgan
# Processing Record 9 of Set 14 | gbarnga
# Processing Record 10 of Set 14 | parsons
# Processing Record 11 of Set 14 | kemin
# Processing Record 12 of Set 14 | namibe
# Processing Record 13 of Set 14 | portland
# Processing Record 14 of Set 14 | amboasary
# Processing Record 15 of Set 14 | san andres
# Processing Record 16 of Set 14 | bridlington
# Processing Record 17 of Set 14 | mati
# Processing Record 18 of Set 14 | tamandare
# Processing Record 19 of Set 14 | paignton
# Processing Record 20 of Set 14 | lyubytino
# Processing Record 21 of Set 14 | foumbot
# Processing Record 22 of Set 14 | sibu
# Processing Record 23 of Set 14 | salamanca
# Processing Record 24 of Set 14 | vila velha
# Processing Record 25 of Set 14 | ballangen
# Processing Record 26 of Set 14 | ojinaga
# Processing Record 27 of Set 14 | isagarh
# Processing Record 28 of Set 14 | abapo
# Processing Record 29 of Set 14 | diphu
# Processing Record 30 of Set 14 | jatai
# Processing Record 31 of Set 14 | ola
# Processing Record 32 of Set 14 | luderitz
# Processing Record 33 of Set 14 | deputatskiy
# Processing Record 34 of Set 14 | meulaboh
# Processing Record 35 of Set 14 | havre-saint-pierre
# Processing Record 36 of Set 14 | cootamundra
# Processing Record 37 of Set 14 | quthing
# Processing Record 38 of Set 14 | grand baie
# Processing Record 39 of Set 14 | inirida
# Processing Record 40 of Set 14 | vallenar
# Processing Record 41 of Set 14 | lake havasu city
# Processing Record 42 of Set 14 | launceston
# Processing Record 43 of Set 14 | baruun-urt
# Processing Record 44 of Set 14 | junin
# Processing Record 45 of Set 14 | pangkalanbuun
# Processing Record 46 of Set 14 | kefalovrison
# City not found. Skipping...
# Processing Record 47 of Set 14 | paamiut
# Processing Record 48 of Set 14 | abiramam
# Processing Record 49 of Set 14 | santiago
# Processing Record 50 of Set 14 | esna
# Processing Record 1 of Set 15 | chaiyaphum
# Processing Record 2 of Set 15 | caxito
# Processing Record 3 of Set 15 | tagbac
# Processing Record 4 of Set 15 | pitanga
# Processing Record 5 of Set 15 | sao felix do xingu
# Processing Record 6 of Set 15 | kharp
# Processing Record 7 of Set 15 | avdon
# Processing Record 8 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 15 | luang prabang
# Processing Record 10 of Set 15 | palma del rio
# Processing Record 11 of Set 15 | tiarei
# Processing Record 12 of Set 15 | carutapera
# Processing Record 13 of Set 15 | awbari
# Processing Record 14 of Set 15 | kwekwe
# Processing Record 15 of Set 15 | waipawa
# Processing Record 16 of Set 15 | omagh
# Processing Record 17 of Set 15 | boca do acre
# Processing Record 18 of Set 15 | monroe
# Processing Record 19 of Set 15 | uarini
# Processing Record 20 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 15 | aranos
# Processing Record 22 of Set 15 | koshurnikovo
# Processing Record 23 of Set 15 | raga
# Processing Record 24 of Set 15 | murgab
# Processing Record 25 of Set 15 | carauari
# Processing Record 26 of Set 15 | karasjok
# Processing Record 27 of Set 15 | flin flon
# Processing Record 28 of Set 15 | yarkovo
# Processing Record 29 of Set 15 | saint-ambroise
# Processing Record 30 of Set 15 | pointe michel
# Processing Record 31 of Set 15 | emba
# Processing Record 32 of Set 15 | omboue
# Processing Record 33 of Set 15 | yeppoon
# Processing Record 34 of Set 15 | shakawe
# Processing Record 35 of Set 15 | conde
# Processing Record 36 of Set 15 | beloha
# Processing Record 37 of Set 15 | gold coast
# Processing Record 38 of Set 15 | ixtapa
# Processing Record 39 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 15 | pokhara
# Processing Record 41 of Set 15 | kudat
# Processing Record 42 of Set 15 | garoua
# Processing Record 43 of Set 15 | butterworth
# Processing Record 44 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 15 | del rio
# Processing Record 46 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 15 | maridi
# Processing Record 48 of Set 15 | sambava
# Processing Record 49 of Set 15 | baijiantan
# Processing Record 50 of Set 15 | ampanihy
# Processing Record 1 of Set 16 | moree
# Processing Record 2 of Set 16 | onufriyivka
# Processing Record 3 of Set 16 | weihe
# Processing Record 4 of Set 16 | dubti
# Processing Record 5 of Set 16 | zakamensk
# Processing Record 6 of Set 16 | krasnoselkup
# Processing Record 7 of Set 16 | moyale
# Processing Record 8 of Set 16 | tiradentes
# Processing Record 9 of Set 16 | komatsu
# Processing Record 10 of Set 16 | kaiyuan
# Processing Record 11 of Set 16 | nishihara
# Processing Record 12 of Set 16 | mundo nuevo
# Processing Record 13 of Set 16 | zahirabad
# Processing Record 14 of Set 16 | sweetwater
# Processing Record 15 of Set 16 | lima
# Processing Record 16 of Set 16 | maykain
# City not found. Skipping...
# Processing Record 17 of Set 16 | gigmoto
# Processing Record 18 of Set 16 | talcahuano
# Processing Record 19 of Set 16 | gilgit
# Processing Record 20 of Set 16 | oranjemund
# Processing Record 21 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 16 | khislavichi
# Processing Record 23 of Set 16 | andenes
# Processing Record 24 of Set 16 | ravar
# Processing Record 25 of Set 16 | chipata
# Processing Record 26 of Set 16 | pacific grove
# Processing Record 27 of Set 16 | ofunato
# Processing Record 28 of Set 16 | esperanza
# Processing Record 29 of Set 16 | dombarovskiy
# Processing Record 30 of Set 16 | umm lajj
# Processing Record 31 of Set 16 | juifang
# City not found. Skipping...
# Processing Record 32 of Set 16 | gazli
# Processing Record 33 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 16 | bull savanna
# Processing Record 35 of Set 16 | atar
# Processing Record 36 of Set 16 | ginda
# Processing Record 37 of Set 16 | stepnyak
# Processing Record 38 of Set 16 | eucaliptus
# Processing Record 39 of Set 16 | havelock
# Processing Record 40 of Set 16 | russell
# Processing Record 41 of Set 16 | yumen
# Processing Record 42 of Set 16 | okha
# Processing Record 43 of Set 16 | xiongshi
# City not found. Skipping...
# Processing Record 44 of Set 16 | chiredzi
# Processing Record 45 of Set 16 | parangan
# Processing Record 46 of Set 16 | tacuarembo
# Processing Record 47 of Set 16 | angra
# City not found. Skipping...
# Processing Record 48 of Set 16 | shu
# Processing Record 49 of Set 16 | trogir
# Processing Record 50 of Set 16 | necocli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred -33.5906   26.8910     71.26        85          74
# 1    Pangnirtung  66.1451  -65.7125     -4.36        75          89
# 2      Ilulissat  69.2167  -51.1000     21.22        68          75
# 3      Grindavik  63.8424  -22.4338     41.47        87          75
# 4          Sitka  57.0531 -135.3300     35.49        69          90
# ..           ...      ...       ...       ...       ...         ...
# 719     Parangan   5.0839  119.9383     81.18        80          96
# 720   Tacuarembo -31.7333  -55.9833     94.06        24          46
# 721          Shu  43.5983   73.7614     42.22        82         100
# 722       Trogir  43.5125   16.2517     44.80        39           0
# 723      Necocli   8.4234  -76.7860     82.08        72          97
#
#      Wind Speed Country                 Date       Description
# 0         15.82      ZA  2021-12-12 16:44:57     broken clouds
# 1          5.53      CA  2021-12-12 16:40:01   overcast clouds
# 2          8.05      GL  2021-12-12 16:44:58     broken clouds
# 3         21.85      IS  2021-12-12 16:44:58     broken clouds
# 4         17.27      US  2021-12-12 16:43:38     moderate rain
# ..          ...     ...                  ...               ...
# 719        2.46      PH  2021-12-12 17:03:22   overcast clouds
# 720        6.08      UY  2021-12-12 17:03:22  scattered clouds
# 721        3.53      KZ  2021-12-12 17:03:22   overcast clouds
# 722       11.50      HR  2021-12-12 17:03:23         clear sky
# 723        6.06      CO  2021-12-12 17:03:23   overcast clouds
#
# [724 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred      ZA -33.5906   26.8910     71.26        85          74
# 1    Pangnirtung      CA  66.1451  -65.7125     -4.36        75          89
# 2      Ilulissat      GL  69.2167  -51.1000     21.22        68          75
# 3      Grindavik      IS  63.8424  -22.4338     41.47        87          75
# 4          Sitka      US  57.0531 -135.3300     35.49        69          90
# ..           ...     ...      ...       ...       ...       ...         ...
# 719     Parangan      PH   5.0839  119.9383     81.18        80          96
# 720   Tacuarembo      UY -31.7333  -55.9833     94.06        24          46
# 721          Shu      KZ  43.5983   73.7614     42.22        82         100
# 722       Trogir      HR  43.5125   16.2517     44.80        39           0
# 723      Necocli      CO   8.4234  -76.7860     82.08        72          97
#
#      Wind Speed       Description
# 0         15.82     broken clouds
# 1          5.53   overcast clouds
# 2          8.05     broken clouds
# 3         21.85     broken clouds
# 4         17.27     moderate rain
# ..          ...               ...
# 719        2.46   overcast clouds
# 720        6.08  scattered clouds
# 721        3.53   overcast clouds
# 722       11.50         clear sky
# 723        6.06   overcast clouds
#
# [724 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
